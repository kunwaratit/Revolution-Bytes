# %% [markdown]
# <a href="https://colab.research.google.com/github/kunwaratit/Revolution-Bytes/blob/main/rev1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Jan 12 08:26:16 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# ### **Detection of Vehicle**

# %%
# !pip install ultralytics
import ultralytics
from ultralytics import YOLO
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.2/699.2 kB 6.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# %cd /content/drive/MyDrive/RevolutionBytes1.0
# Out:
# drive  sample_data
# /content/drive/MyDrive/RevolutionBytes1.0

# %% [markdown]
# ### **Training the model**

# %%
# !yolo detect train data=data.yaml model=yolov8n.pt epochs=100
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 93.8MB/s]
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### **Validate**

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/RevolutionBytes1.0/runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/RevolutionBytes1.0/data/valid/labels.cache... 20 images, 10 backgrounds, 0 corrupt: 100% 29/29 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:08<00:00,  4.19s/it]
#                    all         29        571      0.412      0.546        0.4      0.253
#                    car         29        181      0.492      0.646      0.534      0.362
#              motorbike         29        345      0.552      0.606      0.504      0.315
#                  truck         29          8       0.27        0.5      0.322      0.198
#                    bus         29         37      0.333      0.432      0.241      0.137
# Speed: 0.2ms preprocess, 22.6ms inference, 0.0ms loss, 8.9ms postprocess per image
# ...

# %% [markdown]
# ### **Predict**

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/RevolutionBytes1.0/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/RevolutionBytes1.0/data/test/images/IMG_0584.mp4 save=True
# Out:
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/459) /content/drive/MyDrive/RevolutionBytes1.0/data/test/images/IMG_0584.mp4: 640x384 7 cars, 10 motorbikes, 1 bus, 88.9ms
# video 1/1 (2/459) /content/drive/MyDrive/RevolutionBytes1.0/data/test/images/IMG_0584.mp4: 640x384 8 cars, 11 motorbikes, 1 bus, 9.3ms
# video 1/1 (3/459) /content/drive/MyDrive/RevolutionBytes1.0/data/test/images/IMG_0584.mp4: 640x384 8 cars, 10 motorbikes, 1 bus, 11.7ms
# video 1/1 (4/459) /content/drive/MyDrive/RevolutionBytes1.0/data/test/images/IMG_0584.mp4: 640x384 7 cars, 10 motorbikes, 1 bus, 17.2ms
# video 1/1 (5/459) /content/drive/MyDrive/RevolutionBytes1.0/data/test/images/IMG_0584.mp4: 640x384 7 cars, 10 motorbikes, 1 bus, 10.1ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/RevolutionBytes1.0/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/RevolutionBytes1.0/data/test/images/204.jpg save=True
# Out:
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/RevolutionBytes1.0/data/test/images/204.jpg: 640x480 1 car, 4 motorbikes, 52.3ms
# Speed: 3.8ms preprocess, 52.3ms inference, 95.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ### **Inference**

# %%
# !zip -r weights.zip /content/drive/MyDrive/RevolutionBytes1.0/runs/detect/train/weights
# Out:
#   adding: content/drive/MyDrive/RevolutionBytes1.0/runs/detect/train/weights/ (stored 0%)
#   adding: content/drive/MyDrive/RevolutionBytes1.0/runs/detect/train/weights/last.pt (deflated 10%)
#   adding: content/drive/MyDrive/RevolutionBytes1.0/runs/detect/train/weights/best.pt (deflated 10%)
